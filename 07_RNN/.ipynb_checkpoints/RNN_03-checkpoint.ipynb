# %% [markdown]
# Lo! in the orient when the gracious light
# Lifts up his burning head, each under eye
# Doth homage to his new-appearing sight,
# Serving with looks his sacred majesty;
# And having climb'd the steep-up heavenly hill,
# Resembling strong youth in his middle age,
# yet mortal looks adore his beauty still,
# Attending on his golden pilgrimage;
# But when from highmost pitch, with weary car,
# Like feeble age, he reeleth from the day,
# The eyes, 'fore duteous, now converted are
# From his low tract and look another way:
# So thou, thyself out-going in thy noon,
# Unlook'd on diest, unless thou get a son.

# %%
import tensorflow as tf
import numpy as np
from tensorflow.contrib import rnn
tf.set_random_seed(777)  # reproducibility

# %%
# http://shakespeare.mit.edu/Poetry/sonnet.VII.html

sentence = ("Lo! in the orient when the gracious light"
            "Lifts up his burning head, each under eye"
            "Doth homage to his new-appearing sight,"
            "Serving with looks his sacred majesty;"
            "And having climb'd the steep-up heavenly hill,"
            "Resembling strong youth in his middle age,"
            "yet mortal looks adore his beauty still,"
            "Attending on his golden pilgrimage;"
            "But when from highmost pitch, with weary car,"
            "Like feeble age, he reeleth from the day,"
            "The eyes, 'fore duteous, now converted are"
            "From his low tract and look another way:"
            "So thou, thyself out-going in thy noon,"
            "Unlook'd on diest, unless thou get a son");
print(sentence)
# Out:
# Lo! in the orient when the gracious lightLifts up his burning head, each under eyeDoth homage to his new-appearing sight,Serving with looks his sacred majesty;And having climb'd the steep-up heavenly hill,Resembling strong youth in his middle age,yet mortal looks adore his beauty still,Attending on his golden pilgrimage;But when from highmost pitch, with weary car,Like feeble age, he reeleth from the day,The eyes, 'fore duteous, now converted areFrom his low tract and look another way:So thou, thyself out-going in thy noon,Unlook'd on diest, unless thou get a son

# %%
char_set = list(set(sentence))
char_dic = {w: i for i, w in enumerate(char_set)}
print(set(sentence))
print(char_set)
print(char_dic)
# Out:
# {'F', ',', 'w', 'S', 'T', 'd', 'm', 't', 'g', 'D', 'A', 'h', 'o', 's', 'j', "'", 'U', ':', '!', 'e', 'a', 'c', 'n', ';', 'y', 'u', 'l', 'p', 'R', '-', 'v', ' ', 'f', 'B', 'k', 'i', 'b', 'r', 'L'}
# ['F', ',', 'w', 'S', 'T', 'd', 'm', 't', 'g', 'D', 'A', 'h', 'o', 's', 'j', "'", 'U', ':', '!', 'e', 'a', 'c', 'n', ';', 'y', 'u', 'l', 'p', 'R', '-', 'v', ' ', 'f', 'B', 'k', 'i', 'b', 'r', 'L']
# {'F': 0, ':': 17, ',': 1, '!': 18, 'e': 19, 'w': 2, 'T': 4, 'j': 14, 'k': 34, 'd': 5, 'm': 6, 't': 7, 'g': 8, 'n': 22, 'l': 26, 'p': 27, '-': 29, 'u': 25, 'v': 30, 'f': 32, 'R': 28, 'D': 9, ';': 23, 'B': 33, 'A': 10, 'h': 11, 'y': 24, 'o': 12, 'i': 35, ' ': 31, 's': 13, 'c': 21, 'r': 37, 'b': 36, 'a': 20, 'L': 38, "'": 15, 'S': 3, 'U': 16}

# %%
data_dim = len(char_set)
hidden_size = len(char_set)
num_classes = len(char_set)
sequence_length = 10  # Any arbitrary number

# %%
dataX = []
dataY = []

# %%
for i in range(0, len(sentence) - sequence_length):
    x_str = sentence[i:i + sequence_length]
    y_str = sentence[i + 1: i + sequence_length + 1]
    print(i, x_str, '->', y_str)

    x = [char_dic[c] for c in x_str]  # x str to index
    y = [char_dic[c] for c in y_str]  # y str to index

    dataX.append(x)
    dataY.append(y)

batch_size = len(dataX)
# Out:
# 0 Lo! in the -> o! in the
# 1 o! in the  -> ! in the o
# 2 ! in the o ->  in the or
# 3  in the or -> in the ori
# 4 in the ori -> n the orie
# 5 n the orie ->  the orien
# 6  the orien -> the orient
# 7 the orient -> he orient
# 8 he orient  -> e orient w
# 9 e orient w ->  orient wh
# 10  orient wh -> orient whe
# 11 orient whe -> rient when
# 12 rient when -> ient when
# 13 ient when  -> ent when t
# 14 ent when t -> nt when th
# 15 nt when th -> t when the
# 16 t when the ->  when the
# 17  when the  -> when the g
# 18 when the g -> hen the gr
# 19 hen the gr -> en the gra
# 20 en the gra -> n the grac
# 21 n the grac ->  the graci
# 22  the graci -> the gracio
# 23 the gracio -> he graciou
# 24 he graciou -> e gracious
# 25 e gracious ->  gracious
# 26  gracious  -> gracious l
# 27 gracious l -> racious li
# 28 racious li -> acious lig
# 29 acious lig -> cious ligh
# 30 cious ligh -> ious light
# 31 ious light -> ous lightL
# 32 ous lightL -> us lightLi
# 33 us lightLi -> s lightLif
# 34 s lightLif ->  lightLift
# 35  lightLift -> lightLifts
# 36 lightLifts -> ightLifts
# 37 ightLifts  -> ghtLifts u
# 38 ghtLifts u -> htLifts up
# 39 htLifts up -> tLifts up
# 40 tLifts up  -> Lifts up h
# 41 Lifts up h -> ifts up hi
# 42 ifts up hi -> fts up his
# 43 fts up his -> ts up his
# 44 ts up his  -> s up his b
# 45 s up his b ->  up his bu
# 46  up his bu -> up his bur
# 47 up his bur -> p his burn
# 48 p his burn ->  his burni
# 49  his burni -> his burnin
# 50 his burnin -> is burning
# 51 is burning -> s burning
# 52 s burning  ->  burning h
# 53  burning h -> burning he
# 54 burning he -> urning hea
# 55 urning hea -> rning head
# 56 rning head -> ning head,
# 57 ning head, -> ing head,
# 58 ing head,  -> ng head, e
# 59 ng head, e -> g head, ea
# 60 g head, ea ->  head, eac
# 61  head, eac -> head, each
# 62 head, each -> ead, each
# 63 ead, each  -> ad, each u
# 64 ad, each u -> d, each un
# 65 d, each un -> , each und
# 66 , each und ->  each unde
# 67  each unde -> each under
# 68 each under -> ach under
# 69 ach under  -> ch under e
# 70 ch under e -> h under ey
# 71 h under ey ->  under eye
# 72  under eye -> under eyeD
# 73 under eyeD -> nder eyeDo
# 74 nder eyeDo -> der eyeDot
# 75 der eyeDot -> er eyeDoth
# 76 er eyeDoth -> r eyeDoth
# 77 r eyeDoth  ->  eyeDoth h
# 78  eyeDoth h -> eyeDoth ho
# 79 eyeDoth ho -> yeDoth hom
# 80 yeDoth hom -> eDoth homa
# 81 eDoth homa -> Doth homag
# 82 Doth homag -> oth homage
# 83 oth homage -> th homage
# 84 th homage  -> h homage t
# 85 h homage t ->  homage to
# 86  homage to -> homage to
# 87 homage to  -> omage to h
# 88 omage to h -> mage to hi
# 89 mage to hi -> age to his
# 90 age to his -> ge to his
# 91 ge to his  -> e to his n
# 92 e to his n ->  to his ne
# 93  to his ne -> to his new
# 94 to his new -> o his new-
# 95 o his new- ->  his new-a
# 96  his new-a -> his new-ap
# 97 his new-ap -> is new-app
# 98 is new-app -> s new-appe
# 99 s new-appe ->  new-appea
# 100  new-appea -> new-appear
# 101 new-appear -> ew-appeari
# 102 ew-appeari -> w-appearin
# 103 w-appearin -> -appearing
# 104 -appearing -> appearing
# 105 appearing  -> ppearing s
# 106 ppearing s -> pearing si
# 107 pearing si -> earing sig
# 108 earing sig -> aring sigh
# 109 aring sigh -> ring sight
# 110 ring sight -> ing sight,
# 111 ing sight, -> ng sight,S
# 112 ng sight,S -> g sight,Se
# 113 g sight,Se ->  sight,Ser
# 114  sight,Ser -> sight,Serv
# 115 sight,Serv -> ight,Servi
# 116 ight,Servi -> ght,Servin
# 117 ght,Servin -> ht,Serving
# 118 ht,Serving -> t,Serving
# 119 t,Serving  -> ,Serving w
# 120 ,Serving w -> Serving wi
# 121 Serving wi -> erving wit
# 122 erving wit -> rving with
# 123 rving with -> ving with
# 124 ving with  -> ing with l
# 125 ing with l -> ng with lo
# 126 ng with lo -> g with loo
# 127 g with loo ->  with look
# 128  with look -> with looks
# 129 with looks -> ith looks
# 130 ith looks  -> th looks h
# 131 th looks h -> h looks hi
# 132 h looks hi ->  looks his
# 133  looks his -> looks his
# 134 looks his  -> ooks his s
# 135 ooks his s -> oks his sa
# 136 oks his sa -> ks his sac
# 137 ks his sac -> s his sacr
# 138 s his sacr ->  his sacre
# 139  his sacre -> his sacred
# 140 his sacred -> is sacred
# 141 is sacred  -> s sacred m
# 142 s sacred m ->  sacred ma
# 143  sacred ma -> sacred maj
# 144 sacred maj -> acred maje
# 145 acred maje -> cred majes
# 146 cred majes -> red majest
# 147 red majest -> ed majesty
# 148 ed majesty -> d majesty;
# 149 d majesty; ->  majesty;A
# 150  majesty;A -> majesty;An
# 151 majesty;An -> ajesty;And
# 152 ajesty;And -> jesty;And
# 153 jesty;And  -> esty;And h
# 154 esty;And h -> sty;And ha
# 155 sty;And ha -> ty;And hav
# 156 ty;And hav -> y;And havi
# 157 y;And havi -> ;And havin
# 158 ;And havin -> And having
# 159 And having -> nd having
# 160 nd having  -> d having c
# 161 d having c ->  having cl
# 162  having cl -> having cli
# 163 having cli -> aving clim
# 164 aving clim -> ving climb
# 165 ving climb -> ing climb'
# 166 ing climb' -> ng climb'd
# 167 ng climb'd -> g climb'd
# 168 g climb'd  ->  climb'd t
# 169  climb'd t -> climb'd th
# 170 climb'd th -> limb'd the
# 171 limb'd the -> imb'd the
# 172 imb'd the  -> mb'd the s
# 173 mb'd the s -> b'd the st
# 174 b'd the st -> 'd the ste
# 175 'd the ste -> d the stee
# 176 d the stee ->  the steep
# 177  the steep -> the steep-
# 178 the steep- -> he steep-u
# 179 he steep-u -> e steep-up
# 180 e steep-up ->  steep-up
# 181  steep-up  -> steep-up h
# 182 steep-up h -> teep-up he
# 183 teep-up he -> eep-up hea
# 184 eep-up hea -> ep-up heav
# 185 ep-up heav -> p-up heave
# 186 p-up heave -> -up heaven
# 187 -up heaven -> up heavenl
# 188 up heavenl -> p heavenly
# 189 p heavenly ->  heavenly
# 190  heavenly  -> heavenly h
# 191 heavenly h -> eavenly hi
# 192 eavenly hi -> avenly hil
# 193 avenly hil -> venly hill
# 194 venly hill -> enly hill,
# 195 enly hill, -> nly hill,R
# 196 nly hill,R -> ly hill,Re
# 197 ly hill,Re -> y hill,Res
# 198 y hill,Res ->  hill,Rese
# 199  hill,Rese -> hill,Resem
# 200 hill,Resem -> ill,Resemb
# 201 ill,Resemb -> ll,Resembl
# 202 ll,Resembl -> l,Resembli
# 203 l,Resembli -> ,Resemblin
# 204 ,Resemblin -> Resembling
# 205 Resembling -> esembling
# 206 esembling  -> sembling s
# 207 sembling s -> embling st
# 208 embling st -> mbling str
# 209 mbling str -> bling stro
# 210 bling stro -> ling stron
# 211 ling stron -> ing strong
# 212 ing strong -> ng strong
# 213 ng strong  -> g strong y
# 214 g strong y ->  strong yo
# 215  strong yo -> strong you
# 216 strong you -> trong yout
# 217 trong yout -> rong youth
# 218 rong youth -> ong youth
# 219 ong youth  -> ng youth i
# 220 ng youth i -> g youth in
# 221 g youth in ->  youth in
# 222  youth in  -> youth in h
# 223 youth in h -> outh in hi
# 224 outh in hi -> uth in his
# 225 uth in his -> th in his
# 226 th in his  -> h in his m
# 227 h in his m ->  in his mi
# 228  in his mi -> in his mid
# 229 in his mid -> n his midd
# 230 n his midd ->  his middl
# 231  his middl -> his middle
# 232 his middle -> is middle
# 233 is middle  -> s middle a
# 234 s middle a ->  middle ag
# 235  middle ag -> middle age
# 236 middle age -> iddle age,
# 237 iddle age, -> ddle age,y
# 238 ddle age,y -> dle age,ye
# 239 dle age,ye -> le age,yet
# 240 le age,yet -> e age,yet
# 241 e age,yet  ->  age,yet m
# 242  age,yet m -> age,yet mo
# 243 age,yet mo -> ge,yet mor
# 244 ge,yet mor -> e,yet mort
# 245 e,yet mort -> ,yet morta
# 246 ,yet morta -> yet mortal
# 247 yet mortal -> et mortal
# 248 et mortal  -> t mortal l
# 249 t mortal l ->  mortal lo
# 250  mortal lo -> mortal loo
# 251 mortal loo -> ortal look
# 252 ortal look -> rtal looks
# 253 rtal looks -> tal looks
# 254 tal looks  -> al looks a
# 255 al looks a -> l looks ad
# 256 l looks ad ->  looks ado
# 257  looks ado -> looks ador
# 258 looks ador -> ooks adore
# 259 ooks adore -> oks adore
# 260 oks adore  -> ks adore h
# 261 ks adore h -> s adore hi
# 262 s adore hi ->  adore his
# 263  adore his -> adore his
# 264 adore his  -> dore his b
# 265 dore his b -> ore his be
# 266 ore his be -> re his bea
# 267 re his bea -> e his beau
# 268 e his beau ->  his beaut
# 269  his beaut -> his beauty
# 270 his beauty -> is beauty
# 271 is beauty  -> s beauty s
# 272 s beauty s ->  beauty st
# 273  beauty st -> beauty sti
# 274 beauty sti -> eauty stil
# 275 eauty stil -> auty still
# 276 auty still -> uty still,
# 277 uty still, -> ty still,A
# 278 ty still,A -> y still,At
# 279 y still,At ->  still,Att
# 280  still,Att -> still,Atte
# 281 still,Atte -> till,Atten
# 282 till,Atten -> ill,Attend
# 283 ill,Attend -> ll,Attendi
# 284 ll,Attendi -> l,Attendin
# 285 l,Attendin -> ,Attending
# 286 ,Attending -> Attending
# 287 Attending  -> ttending o
# 288 ttending o -> tending on
# 289 tending on -> ending on
# 290 ending on  -> nding on h
# 291 nding on h -> ding on hi
# 292 ding on hi -> ing on his
# 293 ing on his -> ng on his
# 294 ng on his  -> g on his g
# 295 g on his g ->  on his go
# 296  on his go -> on his gol
# 297 on his gol -> n his gold
# 298 n his gold ->  his golde
# 299  his golde -> his golden
# 300 his golden -> is golden
# 301 is golden  -> s golden p
# 302 s golden p ->  golden pi
# 303  golden pi -> golden pil
# 304 golden pil -> olden pilg
# 305 olden pilg -> lden pilgr
# 306 lden pilgr -> den pilgri
# 307 den pilgri -> en pilgrim
# 308 en pilgrim -> n pilgrima
# 309 n pilgrima ->  pilgrimag
# 310  pilgrimag -> pilgrimage
# 311 pilgrimage -> ilgrimage;
# 312 ilgrimage; -> lgrimage;B
# 313 lgrimage;B -> grimage;Bu
# 314 grimage;Bu -> rimage;But
# 315 rimage;But -> image;But
# 316 image;But  -> mage;But w
# 317 mage;But w -> age;But wh
# 318 age;But wh -> ge;But whe
# 319 ge;But whe -> e;But when
# 320 e;But when -> ;But when
# 321 ;But when  -> But when f
# 322 But when f -> ut when fr
# 323 ut when fr -> t when fro
# 324 t when fro ->  when from
# 325  when from -> when from
# 326 when from  -> hen from h
# 327 hen from h -> en from hi
# 328 en from hi -> n from hig
# 329 n from hig ->  from high
# 330  from high -> from highm
# 331 from highm -> rom highmo
# 332 rom highmo -> om highmos
# 333 om highmos -> m highmost
# 334 m highmost ->  highmost
# 335  highmost  -> highmost p
# 336 highmost p -> ighmost pi
# 337 ighmost pi -> ghmost pit
# 338 ghmost pit -> hmost pitc
# 339 hmost pitc -> most pitch
# 340 most pitch -> ost pitch,
# 341 ost pitch, -> st pitch,
# 342 st pitch,  -> t pitch, w
# 343 t pitch, w ->  pitch, wi
# 344  pitch, wi -> pitch, wit
# 345 pitch, wit -> itch, with
# 346 itch, with -> tch, with
# 347 tch, with  -> ch, with w
# 348 ch, with w -> h, with we
# 349 h, with we -> , with wea
# 350 , with wea ->  with wear
# 351  with wear -> with weary
# 352 with weary -> ith weary
# 353 ith weary  -> th weary c
# 354 th weary c -> h weary ca
# 355 h weary ca ->  weary car
# 356  weary car -> weary car,
# 357 weary car, -> eary car,L
# 358 eary car,L -> ary car,Li
# 359 ary car,Li -> ry car,Lik
# 360 ry car,Lik -> y car,Like
# 361 y car,Like ->  car,Like
# 362  car,Like  -> car,Like f
# 363 car,Like f -> ar,Like fe
# 364 ar,Like fe -> r,Like fee
# 365 r,Like fee -> ,Like feeb
# 366 ,Like feeb -> Like feebl
# 367 Like feebl -> ike feeble
# 368 ike feeble -> ke feeble
# 369 ke feeble  -> e feeble a
# 370 e feeble a ->  feeble ag
# 371  feeble ag -> feeble age
# 372 feeble age -> eeble age,
# 373 eeble age, -> eble age,
# 374 eble age,  -> ble age, h
# 375 ble age, h -> le age, he
# 376 le age, he -> e age, he
# 377 e age, he  ->  age, he r
# 378  age, he r -> age, he re
# 379 age, he re -> ge, he ree
# 380 ge, he ree -> e, he reel
# 381 e, he reel -> , he reele
# 382 , he reele ->  he reelet
# 383  he reelet -> he reeleth
# 384 he reeleth -> e reeleth
# 385 e reeleth  ->  reeleth f
# 386  reeleth f -> reeleth fr
# 387 reeleth fr -> eeleth fro
# 388 eeleth fro -> eleth from
# 389 eleth from -> leth from
# 390 leth from  -> eth from t
# 391 eth from t -> th from th
# 392 th from th -> h from the
# 393 h from the ->  from the
# 394  from the  -> from the d
# 395 from the d -> rom the da
# 396 rom the da -> om the day
# 397 om the day -> m the day,
# 398 m the day, ->  the day,T
# 399  the day,T -> the day,Th
# 400 the day,Th -> he day,The
# 401 he day,The -> e day,The
# 402 e day,The  ->  day,The e
# 403  day,The e -> day,The ey
# 404 day,The ey -> ay,The eye
# 405 ay,The eye -> y,The eyes
# 406 y,The eyes -> ,The eyes,
# 407 ,The eyes, -> The eyes,
# 408 The eyes,  -> he eyes, '
# 409 he eyes, ' -> e eyes, 'f
# 410 e eyes, 'f ->  eyes, 'fo
# 411  eyes, 'fo -> eyes, 'for
# 412 eyes, 'for -> yes, 'fore
# 413 yes, 'fore -> es, 'fore
# 414 es, 'fore  -> s, 'fore d
# 415 s, 'fore d -> , 'fore du
# 416 , 'fore du ->  'fore dut
# 417  'fore dut -> 'fore dute
# 418 'fore dute -> fore duteo
# 419 fore duteo -> ore duteou
# 420 ore duteou -> re duteous
# 421 re duteous -> e duteous,
# 422 e duteous, ->  duteous,
# 423  duteous,  -> duteous, n
# 424 duteous, n -> uteous, no
# 425 uteous, no -> teous, now
# 426 teous, now -> eous, now
# 427 eous, now  -> ous, now c
# 428 ous, now c -> us, now co
# 429 us, now co -> s, now con
# 430 s, now con -> , now conv
# 431 , now conv ->  now conve
# 432  now conve -> now conver
# 433 now conver -> ow convert
# 434 ow convert -> w converte
# 435 w converte ->  converted
# 436  converted -> converted
# 437 converted  -> onverted a
# 438 onverted a -> nverted ar
# 439 nverted ar -> verted are
# 440 verted are -> erted areF
# 441 erted areF -> rted areFr
# 442 rted areFr -> ted areFro
# 443 ted areFro -> ed areFrom
# 444 ed areFrom -> d areFrom
# 445 d areFrom  ->  areFrom h
# 446  areFrom h -> areFrom hi
# 447 areFrom hi -> reFrom his
# 448 reFrom his -> eFrom his
# 449 eFrom his  -> From his l
# 450 From his l -> rom his lo
# 451 rom his lo -> om his low
# 452 om his low -> m his low
# 453 m his low  ->  his low t
# 454  his low t -> his low tr
# 455 his low tr -> is low tra
# 456 is low tra -> s low trac
# 457 s low trac ->  low tract
# 458  low tract -> low tract
# 459 low tract  -> ow tract a
# 460 ow tract a -> w tract an
# 461 w tract an ->  tract and
# 462  tract and -> tract and
# 463 tract and  -> ract and l
# 464 ract and l -> act and lo
# 465 act and lo -> ct and loo
# 466 ct and loo -> t and look
# 467 t and look ->  and look
# 468  and look  -> and look a
# 469 and look a -> nd look an
# 470 nd look an -> d look ano
# 471 d look ano ->  look anot
# 472  look anot -> look anoth
# 473 look anoth -> ook anothe
# 474 ook anothe -> ok another
# 475 ok another -> k another
# 476 k another  ->  another w
# 477  another w -> another wa
# 478 another wa -> nother way
# 479 nother way -> other way:
# 480 other way: -> ther way:S
# 481 ther way:S -> her way:So
# 482 her way:So -> er way:So
# 483 er way:So  -> r way:So t
# 484 r way:So t ->  way:So th
# 485  way:So th -> way:So tho
# 486 way:So tho -> ay:So thou
# 487 ay:So thou -> y:So thou,
# 488 y:So thou, -> :So thou,
# 489 :So thou,  -> So thou, t
# 490 So thou, t -> o thou, th
# 491 o thou, th ->  thou, thy
# 492  thou, thy -> thou, thys
# 493 thou, thys -> hou, thyse
# 494 hou, thyse -> ou, thysel
# 495 ou, thysel -> u, thyself
# 496 u, thyself -> , thyself
# 497 , thyself  ->  thyself o
# 498  thyself o -> thyself ou
# 499 thyself ou -> hyself out
# 500 hyself out -> yself out-
# 501 yself out- -> self out-g
# 502 self out-g -> elf out-go
# 503 elf out-go -> lf out-goi
# 504 lf out-goi -> f out-goin
# 505 f out-goin ->  out-going
# 506  out-going -> out-going
# 507 out-going  -> ut-going i
# 508 ut-going i -> t-going in
# 509 t-going in -> -going in
# 510 -going in  -> going in t
# 511 going in t -> oing in th
# 512 oing in th -> ing in thy
# 513 ing in thy -> ng in thy
# 514 ng in thy  -> g in thy n
# 515 g in thy n ->  in thy no
# 516  in thy no -> in thy noo
# 517 in thy noo -> n thy noon
# 518 n thy noon ->  thy noon,
# 519  thy noon, -> thy noon,U
# 520 thy noon,U -> hy noon,Un
# 521 hy noon,Un -> y noon,Unl
# 522 y noon,Unl ->  noon,Unlo
# 523  noon,Unlo -> noon,Unloo
# 524 noon,Unloo -> oon,Unlook
# 525 oon,Unlook -> on,Unlook'
# 526 on,Unlook' -> n,Unlook'd
# 527 n,Unlook'd -> ,Unlook'd
# 528 ,Unlook'd  -> Unlook'd o
# 529 Unlook'd o -> nlook'd on
# 530 nlook'd on -> look'd on
# 531 look'd on  -> ook'd on d
# 532 ook'd on d -> ok'd on di
# 533 ok'd on di -> k'd on die
# 534 k'd on die -> 'd on dies
# 535 'd on dies -> d on diest
# 536 d on diest ->  on diest,
# 537  on diest, -> on diest,
# 538 on diest,  -> n diest, u
# 539 n diest, u ->  diest, un
# 540  diest, un -> diest, unl
# 541 diest, unl -> iest, unle
# 542 iest, unle -> est, unles
# 543 est, unles -> st, unless
# 544 st, unless -> t, unless
# 545 t, unless  -> , unless t
# 546 , unless t ->  unless th
# 547  unless th -> unless tho
# 548 unless tho -> nless thou
# 549 nless thou -> less thou
# 550 less thou  -> ess thou g
# 551 ess thou g -> ss thou ge
# 552 ss thou ge -> s thou get
# 553 s thou get ->  thou get
# 554  thou get  -> thou get a
# 555 thou get a -> hou get a
# 556 hou get a  -> ou get a s
# 557 ou get a s -> u get a so
# 558 u get a so ->  get a son

# %%
X = tf.placeholder(tf.int32, [None, sequence_length])
Y = tf.placeholder(tf.int32, [None, sequence_length])

# %%
X_one_hot = tf.one_hot(X, num_classes)
print(X_one_hot)  # check out the shape
# Out:
# Tensor("one_hot_2:0", shape=(?, 10, 39), dtype=float32)

# %%
cell = rnn.BasicLSTMCell(hidden_size, state_is_tuple=True, reuse=tf.get_variable_scope().reuse)
cell = rnn.MultiRNNCell([cell] * 2, state_is_tuple=True)
print(cell)
# Out:
# <tensorflow.contrib.rnn.python.ops.core_rnn_cell_impl.MultiRNNCell object at 0x0000025622AFFFD0>

# %%
# outputs: unfolding size x hidden size, state = hidden size
outputs, _states = tf.nn.dynamic_rnn(cell, X_one_hot, dtype=tf.float32)

# FC layer
X_for_fc = tf.reshape(outputs, [-1, hidden_size])
outputs = tf.contrib.layers.fully_connected(X_for_fc, num_classes, activation_fn=None)

# reshape out for sequence_loss
outputs = tf.reshape(outputs, [batch_size, sequence_length, num_classes])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-c1ac5eab05cc> in <module>()
#       1 # outputs: unfolding size x hidden size, state = hidden size
# ----> 2 outputs, _states = tf.nn.dynamic_rnn(cell, X_one_hot, dtype=tf.float32)
#       3
#       4 # FC layer
#       5 X_for_fc = tf.reshape(outputs, [-1, hidden_size])
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\rnn.py in dynamic_rnn(cell, inputs, sequence_length, initial_state, dtype, parallel_iterations, swap_memory, time_major, scope)
#     551         swap_memory=swap_memory,
#     552         sequence_length=sequence_length,
# --> 553         dtype=dtype)
#     554
#     555     # Outputs of _dynamic_rnn_loop are always shaped [time, batch, depth].
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\rnn.py in _dynamic_rnn_loop(cell, inputs, initial_state, parallel_iterations, swap_memory, sequence_length, dtype)
#     718       loop_vars=(time, output_ta, state),
#     719       parallel_iterations=parallel_iterations,
# --> 720       swap_memory=swap_memory)
#     721
#     722   # Unpack final output if not using output tuples.
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name)
#    2621     context = WhileContext(parallel_iterations, back_prop, swap_memory, name)
#    2622     ops.add_to_collection(ops.GraphKeys.WHILE_CONTEXT, context)
# -> 2623     result = context.BuildLoop(cond, body, loop_vars, shape_invariants)
#    2624     return result
#    2625
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in BuildLoop(self, pred, body, loop_vars, shape_invariants)
#    2454       self.Enter()
#    2455       original_body_result, exit_vars = self._BuildLoop(
# -> 2456           pred, body, original_loop_vars, loop_vars, shape_invariants)
#    2457     finally:
#    2458       self.Exit()
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in _BuildLoop(self, pred, body, original_loop_vars, loop_vars, shape_invariants)
#    2404         structure=original_loop_vars,
#    2405         flat_sequence=vars_for_body_with_tensor_arrays)
# -> 2406     body_result = body(*packed_vars_for_body)
#    2407     if not nest.is_sequence(body_result):
#    2408       body_result = [body_result]
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\rnn.py in _time_step(time, output_ta_t, state)
#     703           skip_conditionals=True)
#     704     else:
# --> 705       (output, new_state) = call_cell()
#     706
#     707     # Pack state if using state tuples
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\rnn.py in <lambda>()
#     689
#     690     input_t = nest.pack_sequence_as(structure=inputs, flat_sequence=input_t)
# --> 691     call_cell = lambda: cell(input_t, state)
#     692
#     693     if sequence_length is not None:
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\contrib\rnn\python\ops\core_rnn_cell_impl.py in __call__(self, inputs, state, scope)
#     951                 state, [0, cur_state_pos], [-1, cell.state_size])
#     952             cur_state_pos += cell.state_size
# --> 953           cur_inp, new_state = cell(cur_inp, cur_state)
#     954           new_states.append(new_state)
#     955     new_states = (tuple(new_states) if self._state_is_tuple else
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\contrib\rnn\python\ops\core_rnn_cell_impl.py in __call__(self, inputs, state, scope)
#     239       else:
#     240         c, h = array_ops.split(value=state, num_or_size_splits=2, axis=1)
# --> 241       concat = _linear([inputs, h], 4 * self._num_units, True)
#     242
#     243       # i = input_gate, j = new_input, f = forget_gate, o = output_gate
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\contrib\rnn\python\ops\core_rnn_cell_impl.py in _linear(args, output_size, bias, bias_start)
#    1042   with vs.variable_scope(scope) as outer_scope:
#    1043     weights = vs.get_variable(
# -> 1044         _WEIGHTS_VARIABLE_NAME, [total_arg_size, output_size], dtype=dtype)
#    1045     if len(args) == 1:
#    1046       res = math_ops.matmul(args[0], weights)
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter)
#    1047       collections=collections, caching_device=caching_device,
#    1048       partitioner=partitioner, validate_shape=validate_shape,
# -> 1049       use_resource=use_resource, custom_getter=custom_getter)
#    1050 get_variable_or_local_docstring = (
#    1051     """%s
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter)
#     946           collections=collections, caching_device=caching_device,
#     947           partitioner=partitioner, validate_shape=validate_shape,
# --> 948           use_resource=use_resource, custom_getter=custom_getter)
#     949
#     950   def _get_partitioned_variable(self,
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter)
#     354           reuse=reuse, trainable=trainable, collections=collections,
#     355           caching_device=caching_device, partitioner=partitioner,
# --> 356           validate_shape=validate_shape, use_resource=use_resource)
#     357
#     358   def _get_partitioned_variable(
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource)
#     339           trainable=trainable, collections=collections,
#     340           caching_device=caching_device, validate_shape=validate_shape,
# --> 341           use_resource=use_resource)
#     342
#     343     if custom_getter is not None:
#
# c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource)
#     651                          " Did you mean to set reuse=True in VarScope? "
#     652                          "Originally defined at:\n\n%s" % (
# --> 653                              name, "".join(traceback.format_list(tb))))
#     654       found_var = self._vars[name]
#     655       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Variable rnn/multi_rnn_cell/cell_0/basic_lstm_cell/weights already exists, disallowed. Did you mean to set reuse=True in VarScope? Originally defined at:
#
#   File "c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\ops.py", line 1228, in __init__
#     self._traceback = _extract_stack()
#   File "c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\ops.py", line 2336, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "c:\users\2e313jcp\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 768, in apply_op
#     op_def=op_def)
