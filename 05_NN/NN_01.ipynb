# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import time
import random

# %%
data_x = np.array([[0,0],[0,1],[1,0],[1,1]],dtype=np.float32)
data_y = np.array([[0],[1],[1],[0]],dtype=np.float32)

# %%
X = tf.placeholder(tf.float32, [None, 2])
Y = tf.placeholder(tf.float32,[None,1])

W = tf.Variable(tf.random_normal([2,1]))
b = tf.Variable(tf.random_normal([1]))

# %%
Hypothesis = tf.sigmoid(tf.matmul(X,W) + b)

# %%
cost = - tf.reduce_mean(Y * tf.log(Hypothesis) + (1 - Y) * tf.log(1 - Hypothesis))

# %%
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# %%
predict = tf.cast(Hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predict,Y),dtype=tf.float32))

# %%
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# %%
for step in range(10001):
        sess.run(train, feed_dict={X: data_x, Y: data_y})
        if step % 200 == 0:
            print(step, sess.run(cost, feed_dict={X: data_x, Y: data_y}), sess.run(W))
h, c, a = sess.run([Hypothesis, predict, accuracy], feed_dict={X: data_x, Y: data_y})
print("\nHypothesis: ", h, "\nCorrect: ", c, "\nAccuracy: ", a)
# Out:
# 0 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 200 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 400 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 600 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 800 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 1000 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 1200 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 1400 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 1600 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 1800 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 2000 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 2200 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 2400 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 2600 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 2800 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 3000 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 3200 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 3400 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 3600 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 3800 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 4000 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 4200 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 4400 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 4600 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 4800 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 5000 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 5200 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 5400 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 5600 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 5800 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 6000 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 6200 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 6400 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 6600 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 6800 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 7000 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 7200 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 7400 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 7600 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 7800 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 8000 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 8200 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 8400 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 8600 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 8800 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 9000 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 9200 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 9400 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 9600 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 9800 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
# 10000 0.693147 [[ -1.22654399e-07]
#  [ -1.22982271e-07]]
#
# Hypothesis:  [[ 0.5]
#  [ 0.5]
#  [ 0.5]
#  [ 0.5]]
# Correct:  [[ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]
# Accuracy:  0.5
